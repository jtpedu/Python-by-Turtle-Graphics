# %% [markdown]
# # 🐢タートルグラフィックスの始め方🐢
# 👇のコマンド入力欄(セルと呼びます)の左にある「▶」ボタンを押して実行してみましょう。
# すると白いキャンバスに緑のカメが表示されます。
# これで準備は完了です❗😽😽😽😽😽

# %%
#############################################################################################################
#👈にある再生ボタンをクリックして実行してください。そうすればタートルグラフィックスのための準備は完了です！#
#############################################################################################################
# %pip install ColabTurtle
from ColabTurtle.Turtle import *
initializeTurtle()
speed(1)
bgcolor('white')
pencolor('green')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %% [markdown]
# かわいいカメさん！ 🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢
# ちなみに実行はプログラム文を入力中にCtrl+Enter(MacOSならCommand+Enter)でもできますよ！

# %% [markdown]
# ******
# # 🐢おさらいと本日のミッション🐢
# 先週みんなで正方形を作った時、
#
# ペンをキャンバスに置く方法、100進んでもらう方法、カメを90度回転させる方法を学びましたね。
#
# 皆さん覚えていますか。
#
# 🤔🤔🤔🤔🤔🤔🤔🤔
#
# 覚えてない？大丈夫！！
#
# 👇の命令文を入力して、カメさんを「┌」みたいな図形を描きましょう。
#
# 初めての方も試してみてくださーい！！

# %%
##########################################
#👇に
# pendown()
# forward(100)
# right(90)
# forward(100)
# と入力して実行してみてください。
#########################################

# %% [markdown]
# すごい！！よくできましたね！！
#
# ポイントを👇にまとめました。
#
# > ・「ペンを置け」：pendown()
#
#
# > ・「前へ進め！」：forward()
#
#
# > ・「右へ曲がれ」：right()
#
#
# > ・カッコの中に数字をいれることで進む長さ、曲がる角度を自由に決めれます。
#
# *****
#
#
#
# さて、今週はそれに踏まえて、
#
# 対角線を結んで出来る五芒星★を作ってみましょう！
#
# 先週より少しレベルアップしますが、
#
# 自信を持って試してみてくださーい😽😽😽😽😽

# %% [markdown]
# ************
# # 🐢Step1: 線を引いてみましょう🐢
# 五芒星★は互いに交差する長さの等しい5本の線分で構成されていますね。
#
# まず★の一番左の頂点から右の頂点まで、線を引いてみましょう。

# %%
##########################################
# まず
# home()
# clear()
# を入力してリセットしましょう
##########################################

# %%
##########################################
#👇にコードを入力して実行してみてください。
#########################################

# %% [markdown]
# 🐢が線を引いてくれました！すごい！🎉🎉🎉🎉🎉🎉

# %% [markdown]
# **********
#
# # 🐢Step2: 🐢さんを回転させましょう🐢
#
# 🐢さんの進行方向はプログラム文で数字で表れますね。例えばright(90)。
#
# 同様に、★を作るために、星の各角の角度を知らなければいけないです。
#
# ★の左下隅に到達するために、🐢さんは次に右へどのくらい曲がればいいでしょうか。
#
# （ヒント🔍：五芒星の先端の内角は36度）
#
# 🤔🤔🤔🤔🤔🤔🤔🤔
#
# ❗❗❗❗❗❗
#
#
# お見事です！
#
# 図を描いてみたらより分かりやすいですよ！
#
# 🐢さん今の所在点、左下隅の頂点という2点間の角度を計算すればいいでしょう。
#
# 正解は180度-36度=144度です！
#
# では、早速コードを入力して実行してみましょう。

# %%
##########################################
#👇にコードを入力して実行してみてください。
#########################################

# %% [markdown]
# 🐢さんはうまく動いてくれましたね！

# %% [markdown]
# ******
# #🐢Step3: 繰り返し処理を行いましょう🐢
# 今は★の三つ目の頂点にたどり着きましたね。
#
# 👆の命令をさらに3回すれば🐢さんは★の五つ目の先端に到達できます。
#
# ではまず👇の命令文を実行して皆さんの推測を検証してみましょう。

# %%
##########################################
#👇にコードを入力して実行してみてください。
#########################################

# %% [markdown]
# 見事にできましたね！！おめでとうございます！！🎉🎉🎉🎉🎉🎉
#
# でも、このような手動でコードを重ねていく方法は、ちょっと「面倒くさい😣」と思いませんか。
#
# ここでより簡単なやり方を皆さんに紹介しますね！
#
# 👇👇👇👇👇👇👇👇
#
# 実はPythonでは、for文による繰り返し処理ができます！
#
# そしてfor文で、組み込み関数である range() 関数を使うと、指定回数分だけの処理が行われます。
#
# サンプル文はこんな感じです👇👇
#
# # for i in range(5):
#
# # 【字下げ】繰り返し処理①
#
# # 【字下げ】繰り返し処理②
#
# 今度は🐢を頂点の間に5回移動させるため、()に5を入れて、
#
# 先ほどと同じような処理文をその下に入力すると、
#
# 5回まで繰り返し処理が行われます。
#
# 今回の処理の流れはどん感じでしょう〜
#
# 皆さんもう分かりましたか。
#
# ⚠️
#
# ※ for文の条件文の直後に :（コロン） を付けてね〜🐢
#
# ※ 処理を書く際は、インデントと呼ばれる半角スペースを入れてね〜🐢

# %%
##########################################
# まず
# home()
# clear()
# を入力してリセットしましょう
##########################################

# %%
##########################################
#👇に答えを入力して実行してみてください。
#########################################

# %% [markdown]
# あれ❓❓❓★はちょっと歪んでいませんか！😺😺😺😺😺
#
# 大丈夫です！コードを少し編集すれば★を水平に保つことができますよ〜
#
# 👇の指示にしたがってみてください！

# %%
##########################################
# まずコードを入力して1本目の線に戻りましょう。
##########################################

# %% [markdown]
# 🐢さんは既に二つ目の頂点にたどり着いたので、
#
# 繰り返し処理をさらに5-1=4回すれば五つ目の頂点に到達できますね。
#
# 先ほどのfor文の条件は「for i in range(5):」でしたが、
#
# 今回は(5)→(4)に変更すれば良いでしょう〜

# %%
##########################################
#👇に答えを入力して実行してみてください。
##########################################

# %% [markdown]
# 🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢🐢

# %% [markdown]
# ******
# # ★ができましたか？
# さすが！あなたはたった数十分でコンピュータに何個も命令ができるようになったわけですね！
# めっちゃカッコいい❗❗😻😻😻😻
#
# ぜひあなたの作品を皆さんに共有してみてください！
#
# 👉https://forms.office.com/Pages/ResponsePage.aspx?id=RZxMVaXXBUSJtCP4s7MsCCl976eBnelIieBxpi83jVpUODVJQ1NUVkszSDZDQkQyQjZYVzFPSEhTVi4u
#
# # 今回はここまで！
# もっといろんなことを試したい？ここはいつでも自由に使えますよ！
